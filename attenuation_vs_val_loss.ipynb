# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

filename = "/Users/huayanwang/nanoGPT/results.pkl"
with open(filename, "rb") as fp:
    attenution_factors, val_losses = pickle.load(fp)

for k in val_losses:
    plt.plot(val_losses[k], label = k)
plt.legend()
    
#attenution_factors= [10, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000, 500000, 1000000, 2000000, 5000000, 10000000, 20000000, 50000000, 100000000, 200000000, 500000000, 1000000000, 2000000000, 5000000000, 10000000000, 20000000000, 50000000000]
#val_losses= [2.28330397605896, 2.208571195602417, 1.994812250137329, 1.913347601890564, 1.92990243434906, 1.9651992321014404, 1.8843177556991577, 1.8473154306411743, 1.9225444793701172, 1.9049285650253296, 1.8596723079681396, 1.9145708084106445, 1.9219844341278076, 1.9138036966323853, 1.898935079574585, 1.892348289489746, 1.9045480489730835, 1.9047027826309204, 1.920882225036621, 1.9214794635772705, 1.8600393533706665, 1.880476713180542, 1.8897908926010132, 1.940670371055603, 1.8800948858261108, 1.8829700946807861, 1.9323806762695312, 1.8977504968643188, 1.878056526184082, 1.92172372341156]
#plt.plot(val_losses)

# %%
attenution_factors= [10, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000, 500000, 1000000, 2000000, 5000000, 10000000, 20000000, 50000000, 100000000, 200000000, 500000000, 1000000000, 2000000000, 5000000000, 10000000000, 20000000000, 50000000000]
val_losses= [2.5268802642822266, 2.44073224067688, 2.1108622550964355, 1.9867589473724365, 1.9647127389907837, 1.9655498266220093, 1.8879344463348389, 1.8466755151748657, 1.9215812683105469, 1.9048206806182861, 1.8595964908599854, 1.91460382938385, 1.9220373630523682, 1.9137895107269287, 1.8989394903182983, 1.8923547267913818, 1.904547929763794, 1.90470290184021, 1.9208831787109375, 1.9214801788330078, 1.8600393533706665, 1.880476713180542, 1.8897908926010132, 1.9406706094741821, 1.8800948858261108, 1.8829700946807861, 1.9323806762695312, 1.8977504968643188, 1.878056526184082, 1.92172372341156]
plt.plot(val_losses)

# %%
import torch

# %%
torch.randn((2,3))
# Out:
# tensor([[-0.5216,  0.6399,  1.4599],
#         [-0.1111,  0.0285,  0.3169]])
